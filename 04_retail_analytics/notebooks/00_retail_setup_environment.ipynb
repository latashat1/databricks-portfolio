# %% [markdown]
# # 00 - Environment Setup: Retail Analytics
#
# **Project:** Retail Analytics & Product Dimension History
#
# **Author:** Latasha Terry
#
# **Last updated:** 9/2/2026
#
# ## What this notebook does
# Creates the Unity Catalog schema and Volumes used by every other notebook in
# this project.
#
# ## Objects created
# - Schema: `main.retail_analytics`
# - Volume: `main.retail_analytics.raw_data` (landing zone for source files)
# - Volume: `main.retail_analytics.checkpoints` (streaming checkpoints, if used)

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS main.retail_analytics
COMMENT 'Retail sales, product dimension (with SCD Type 2 history), customer, and store data for retail analytics';

CREATE VOLUME IF NOT EXISTS main.retail_analytics.raw_data
COMMENT 'Landing zone for raw CSV extracts';

CREATE VOLUME IF NOT EXISTS main.retail_analytics.checkpoints
COMMENT 'Streaming checkpoint locations';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
